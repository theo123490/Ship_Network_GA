# %%
import pandas as pd
import numpy as np

# %%
def read_excel(data):
    df = pd.read_excel('Data Prep.xlsx', index_col=0, sheet_name=data)
    return df

def delete_x_row(df,x):
    df = df[x:]
    return df

# %%
alpha_up = read_excel('alpha_up')

GAMMA_TL = read_excel('GAMMA_TL')

w = read_excel('w')

u_char = read_excel('u_char')

TL_char = read_excel('TL_char')

beta_up = read_excel('beta_up')

gamma_uu = read_excel('gamma_uu')
gamma_uu = gamma_uu.fillna(0)
gamma_uu = gamma_uu + gamma_uu.T

SIGMA_PL = read_excel('SIGMA_PL')

p_char = read_excel('p_char')

PL_char = read_excel('PL_char')

sigma_pr = read_excel('sigma_pr')

PSI_PR = read_excel('PSI_PR')

z_pr = read_excel('z_pr')

r_char = read_excel('r_char')

PR_char = read_excel('PR_char')

# %%
alpha_up
# Out:
#                Namlea  Namrole  Moa  Saumlaki  Kisar  Dobo
# Tanjung Perak      25       20   15        18     15    25
# Makassar           15       25   25        30     20    15

# %%
GAMMA_TL
# Out:
#                    Namlea     Namrole         Moa    Saumlaki       Kisar  \
# Tanjung Perak  4362124.80  4044053.20  4184913.48  5048250.68  4003158.28
# Makassar       2335554.32  2017482.72  2158343.00  3021680.20  1976587.80
#
#                      Dobo
# Tanjung Perak  5861605.20
# Makassar       3835034.72

# %%
w
# Out:
#                Tanjung Priok  Tanjung Perak  Makassar  Namlea  Namrole    Moa  \
# Tanjung Priok            0.0          360.0     806.0     NaN      NaN    NaN
# Tanjung Perak            NaN            0.0     446.0   960.0    890.0  921.0
# Makassar                 NaN            NaN       0.0   514.0    444.0  475.0
# Namlea                   NaN            NaN       NaN     0.0     70.0  316.0
# Namrole                  NaN            NaN       NaN     NaN      0.0  246.0
# Moa                      NaN            NaN       NaN     NaN      NaN    0.0
# Saumlaki                 NaN            NaN       NaN     NaN      NaN    NaN
# Kisar                    NaN            NaN       NaN     NaN      NaN    NaN
# Dobo                     NaN            NaN       NaN     NaN      NaN    NaN
# Ambon                    NaN            NaN       NaN     NaN      NaN    NaN
# Tual                     NaN            NaN       NaN     NaN      NaN    NaN
# Banda Neira              NaN            NaN       NaN     NaN      NaN    NaN
# Saumlaki                 NaN            NaN       NaN     NaN      NaN    NaN
#
#                Saumlaki  Kisar    Dobo   Ambon    Tual   Banda  Saumlaki.1
# Tanjung Priok       NaN    NaN  1650.0  1342.0  1565.0  1397.0      1471.0
# Tanjung Perak    1111.0  881.0  1290.0   982.0  1205.0  1037.0      1111.0
# Makassar          665.0  435.0   844.0   536.0   759.0   591.0       665.0
# Namlea            385.0  297.0   478.0     NaN     NaN     NaN         NaN
# Namrole           315.0  227.0   408.0     NaN     NaN     NaN         NaN
# Moa               207.0   40.0   407.0     NaN     NaN     NaN         NaN
# Saumlaki            0.0  247.0   228.0     NaN     NaN     NaN         NaN
# Kisar               NaN    0.0   444.0     NaN     NaN     NaN         NaN
# Dobo                NaN    NaN     NaN     NaN     NaN     NaN         NaN
# Ambon               NaN    NaN   420.0     NaN   312.0   126.0       330.0
# Tual                NaN    NaN   103.0     NaN     NaN   183.0       185.0
# Banda Neira         NaN    NaN   286.0     NaN     NaN     NaN       238.0
# Saumlaki            NaN    NaN   228.0     NaN     NaN     NaN         NaN

# %%
u_char
# Out:
#                          Namlea       Namrole           Moa      Saumlaki  \
# Pelabuhan Tujuan
# D_p_TL                40.000000     45.000000     40.000000     48.000000
# t_p_TL               120.000000    120.000000    120.000000    120.000000
# B_p_TL                 4.000000      4.000000      4.000000      4.000000
# S_p                    3.000000      3.000000      3.000000      3.000000
# C_p_bmTL           20000.000000  20000.000000  20000.000000  20000.000000
# C_p_st               183.333333    183.333333    183.333333    183.333333
# T_k                15000.000000  15000.000000  15000.000000  15000.000000
#
#                           Kisar          Dobo
# Pelabuhan Tujuan
# D_p_TL                35.000000     40.000000
# t_p_TL               120.000000    120.000000
# B_p_TL                 4.000000      4.000000
# S_p                    3.000000      3.000000
# C_p_bmTL           20000.000000  20000.000000
# C_p_st               183.333333    183.333333
# T_k                15000.000000  15000.000000

# %%
TL_char
# Out:
#        value
# V_TL      12
# VC_TL    100

# %%
beta_up
# Out:
#                Ambon  Tual  Banda  Saumlaki  Dobo
# Tanjung Priok     15    10     12        15    20
# Tanjung Perak     20    25     20        15    15
# Makassar          10    12      8         5     5

# %%
gamma_uu
# Out:
#                Tanjung Priok  Tanjung Perak  Makassar
# Tanjung Priok            0.0           20.0      15.0
# Tanjung Perak           20.0            0.0      30.0
# Makassar                15.0           30.0       0.0

# %%
SIGMA_PL
# Out:
#                Tanjung Perak    Makassar       Ambon        Tual  Banda Neira  \
# Tanjung Priok      1635796.8  3662367.28  6097886.96  7111172.20   6347800.36
# Tanjung Perak            NaN  2026570.48  4462090.16  5475375.40   4712003.56
# Makassar                 NaN         NaN  2435519.68  3448804.92   2685433.08
#
#                  Saumlaki        Dobo
# Tanjung Priok  6684047.48  7497402.00
# Tanjung Perak  5048250.68  5861605.20
# Makassar       3021680.20  3835034.72

# %%
p_char
# Out:
#            Tanjung Perak  Makassar         Ambon          Tual         Banda  \
# D_p_pl                20        45     45.000000     47.000000     40.000000
# t_p_pl                 8         4      4.000000      3.000000      3.000000
# B_u`_PL                2         2      0.000000      0.000000      0.000000
# B_p_PL                 0         0      2.000000      2.000000      2.000000
# S_u`                  72        72      0.000000      0.000000      0.000000
# S_p                    0         0     72.000000     24.000000     24.000000
# C_u`_bmPL          20000     20000      0.000000      0.000000      0.000000
# C_p_bmPL               0         0  20000.000000  20000.000000  20000.000000
# C_u`_st              375       375      0.000000      0.000000      0.000000
# C_p_st                 0         0    354.166667    354.166667    354.166667
# T_k                15000     15000  15000.000000  15000.000000  15000.000000
#
#                Saumlaki          Dobo
# D_p_pl        35.000000     40.000000
# t_p_pl         3.000000      3.000000
# B_u`_PL        0.000000      0.000000
# B_p_PL         2.000000      2.000000
# S_u`           0.000000      0.000000
# S_p           24.000000     24.000000
# C_u`_bmPL      0.000000      0.000000
# C_p_bmPL   20000.000000  20000.000000
# C_u`_st        0.000000      0.000000
# C_p_st       354.166667    354.166667
# T_k        15000.000000  15000.000000

# %%
PL_char
# Out:
#        value
# V_pl      20
# VC_pl     50

# %%
sigma_pr
# Out:
#              Ambalau  Wamsisi  Leksula   Tifu  Waemulang   Fogi  Manipa  \
# Ambon           23.0     10.0     21.0   14.0        9.0   12.0    32.0
# Tual             NaN      NaN      NaN    NaN        NaN    NaN     NaN
# Saumlaki         NaN      NaN      NaN    NaN        NaN    NaN     NaN
# Dobo             NaN      NaN      NaN    NaN        NaN    NaN     NaN
# Namrole        156.0    110.0    104.0  145.0      165.0    7.0    10.0
# Banda Neira      NaN      NaN      NaN    NaN        NaN    NaN     NaN
# Moa              NaN      NaN      NaN    NaN        NaN    NaN     NaN
# Namlea           2.0      6.0      4.0    5.0        7.0  100.0   120.0
# Kisar            NaN      NaN      NaN    NaN        NaN    NaN     NaN
#
#              Kelang  Buano  Taniwel  ...  Bebar   Eray  Ilwaki  Romang  \
# Ambon          16.0  360.0    390.0  ...    NaN    NaN     NaN     NaN
# Tual            NaN    NaN      NaN  ...    NaN    NaN     NaN     NaN
# Saumlaki        NaN    NaN      NaN  ...   44.0    NaN    34.0     NaN
# Dobo            NaN    NaN      NaN  ...    NaN    NaN     NaN     NaN
# Namrole        11.0   24.0     14.0  ...    NaN    NaN     NaN     NaN
# Banda Neira     NaN    NaN      NaN  ...    NaN    NaN     NaN     NaN
# Moa             NaN    NaN      NaN  ...  204.0    NaN     NaN     NaN
# Namlea        145.0   10.0     23.0  ...    NaN    NaN     NaN     NaN
# Kisar           NaN    NaN      NaN  ...    NaN  191.0   187.0   180.0
#
#              Arwala/ Sutilirang  Kisar 1  P. Leti  Lakor  P. Luang  Lelang
# Ambon                       NaN      NaN      NaN   12.0      14.0     NaN
# Tual                        NaN      NaN      NaN    NaN       NaN     NaN
# Saumlaki                   46.0      NaN      3.0    NaN       NaN    20.0
# Dobo                        NaN      NaN      NaN    NaN       NaN     NaN
# Namrole                     NaN      NaN      NaN    NaN       NaN     NaN
# Banda Neira                 NaN      NaN      NaN    NaN       NaN     NaN
# Moa                        17.0      NaN    120.0  178.0     155.0   180.0
# Namlea                      NaN      NaN      NaN    NaN       NaN     NaN
# Kisar                     220.0    156.0     40.0   30.0      20.0    24.0
#
# [9 rows x 70 columns]

# %%
PSI_PR
# Out:
#               Ambalau   Wamsisi    Leksula      Tifu  Waemulang       Fogi  \
# Ambon        11584.72  15101.51   24203.79  21100.74   26065.62   29996.15
# Tual         71783.89  75507.55   84609.83  81713.65   86264.79   90195.32
# Saumlaki     72818.24  76335.03   85023.57  81920.52   86678.53   90609.06
# Dobo         90195.32  93918.98  102400.65  99504.47  104055.61  107986.14
# Namrole       9309.15   2689.31    5999.23   2896.18    7240.45   11377.85
# Banda Neira  33926.68  37443.47   46132.01  43028.96   47786.97   51717.50
# Namlea          56       93  ...    267   291     322     297
# Kisar          319      354  ...    118    93      45      33
#
#              Arwala/ Sutilirang  Kisar 1  P. Leti  Lakor  P. Luang  Lelang
# Ambon                       253      275      270    277       277     288
# Tual                        380      371      344    321       294     285
# Saumlaki                    269      247      218    187       154     141
# Dobo                        458      446      417    394       368     369
# Namrole                     232      262      279    296       318     333
# Banda Neira                 263      271      256    243       242     230
# Moa                          65       41       11     23        52      66
# Namlea                      285      314      301    311       317     328
# Kisar                        31       38       31     64        92     107
#
# [9 rows x 70 columns]

# %%
r_char
# Out:
#              Ambalau     Wamsisi     Leksula        Tifu   Waemulang  \
# D_r_PR    181.000000  126.000000  129.000000  164.000000  181.000000
# t_r_PR     24.000000   24.000000   24.000000   24.000000   24.000000
# B_r_PR      5.000000    5.000000    5.000000    5.000000    5.000000
# S_r         3.000000    3.000000    3.000000    3.000000    3.000000
# C_r_bmPR  700.000000  700.000000  700.000000  700.000000  700.000000
# C_r_st     22.916667   22.916667   22.916667   22.916667   22.916667
# T_g       900.000000  900.000000  900.000000  900.000000  900.000000
#
#                 Fogi      Manipa      Kelang       Buano     Taniwel  ...  \
# D_r_PR    119.000000  162.000000  172.000000  394.000000  427.000000  ...
# t_r_PR     24.000000   24.000000   24.000000   24.000000   24.000000  ...
# B_r_PR      5.000000    5.000000    5.000000    5.000000    5.000000  ...
# S_r         3.000000    3.000000    3.000000    3.000000    3.000000  ...
# C_r_bmPR  700.000000  700.000000  700.000000  700.000000  700.000000  ...
# C_r_st     22.916667   22.916667   22.916667   22.916667   22.916667  ...
# T_g       900.000000  900.000000  900.000000  900.000000  900.000000  ...
#
#                Bebar        Eray      Ilwaki      Romang  Arwala/ Sutilirang  \
# D_r_PR    248.000000  191.000000  221.000000  180.000000          283.000000
# t_r_PR     24.000000   24.000000   24.000000   24.000000           24.000000
# B_r_PR      5.000000    5.000000    5.000000    5.000000            5.000000
# S_r         3.000000    3.000000    3.000000    3.000000            3.000000
# C_r_bmPR  700.000000  700.000000  700.000000  700.000000          700.000000
# C_r_st     22.916667   22.916667   22.916667   22.916667           22.916667
# T_g       900.000000  900.000000  900.000000  900.000000          900.000000
#
#              Kisar 1     P. Leti       Lakor    P. Luang      Lelang
# D_r_PR    156.000000  163.000000  220.000000  189.000000  224.000000
# t_r_PR     24.000000   24.000000   24.000000   24.000000   24.000000
# B_r_PR      5.000000    5.000000    5.000000    5.000000    5.000000
# S_r         3.000000    3.000000    3.000000    3.000000    3.000000
# C_r_bmPR  700.000000  700.000000  700.000000  700.000000  700.000000
# C_r_st     22.916667   22.916667   22.916667   22.916667   22.916667
# T_g       900.000000  900.000000  900.000000  900.000000  900.000000
#
# [7 rows x 70 columns]

# %%
PR_char
# Out:
#        values
# V_PR       12
# VC_PR     500

# %%
w = w.fillna(w.mean())
SIGMA_PL = SIGMA_PL.fillna(SIGMA_PL.mean())
sigma_pr = sigma_pr.fillna(sigma_pr.mean())
